# %% [markdown]
# # Fitting for the Hubble constant
#
# We will use Hubble's [original paper](https://www.pnas.org/content/15/3/168) to compute Hubble's constant from a linear fit to distance versus velocity of extra-galactic nebulae.

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

from least_squares import least_squares

# %%
# Make the plots a bit bigger to see
# NOTE: Must be done in a separate cell
plt.rcParams['figure.dpi'] = 100

# %%
# distances in Mpc
r = np.array([ 0.032, 0.034, 0.214, 0.263, 0.275, 0.275, 0.45, 0.5,
      0.5,   0.63,  0.8,   0.9,   0.9,   0.9,   0.9,  1.0,
      1.1,   1.1,   1.4,   1.7,   2.0,   2.0,   2.0,  2.0 ])

# velocities in km/s
v = np.array([ +170, +290, -130, -70,  -185, -220, +200, +290,
      +270, +200, +300, -30,  +650, +150, +500, +920,
      +450, +500, +500, +960, +500, +850, +800, +1090 ])


n = len(r)   # number of galaxies

if n <= 2 :
    print ('Error! Need at least two data points!')
    exit()

# Use our home-grown version
[a, b, sigma, sigma_a, sigma_b] = least_squares(r,v)

# Check against numpy's version:
p,cov = np.polyfit( r, v, 1, cov=True)

# Print out results
print (' Least squares fit of', n, 'data points')
print (' -----------------------------------')
print (" Hubble's constant slope   b = {0:6.2f} +- {1:6.2f}  km/s/Mpc".format( b, sigma_b))
print (" Intercept with r axis     a = {0:6.2f} +- {1:6.2f}  km/s".format( a, sigma_a))
print (' Estimated v error bar sigma =', round(sigma, 1), 'km/s')
print (" numpy's values:           b = {0:6.2f} +- {1:6.2f}  km/s/Mpc".format( p[0], np.sqrt(cov[0,0])))
print ("                           a = {0:6.2f} +- {1:6.2f}  km/s/Mpc".format( p[1], np.sqrt(cov[1,1])))


rvals = np.linspace(0., 2.0, 21)
f = a + b * rvals
fnp = p[1] + p[0] * rvals
plt.figure(1)
plt.scatter( r, v, label = "Data" )
plt.plot( rvals, f , label="Our fit")
plt.plot( rvals, fnp, label = "numpy fit")
plt.xlabel("Distance (Mpc)")
plt.ylabel("Velocity (km/s)")
plt.legend()

plt.show()
# Out:
#  Least squares fit of 24 data points
#  -----------------------------------
#  Hubble's constant slope   b = 454.16 +-  75.24  km/s/Mpc
#  Intercept with r axis     a = -40.78 +-  83.44  km/s
#  Estimated v error bar sigma = 232.9 km/s
#  numpy's values:           b = 454.16 +-  75.24  km/s/Mpc
#                            a = -40.78 +-  83.44  km/s/Mpc

# %% [markdown]
# $\textbf{Solution :}$
# Hubble in his paper (Hubble, E. (1929). A relation between distance and radial velocity among extra-galactic nebulae. Proceedings of the national academy of sciences, 15(3), 168-173.) , sorts the galaxies into 9 clusters. He mentiones that it is done based on the proximity of the galaxies with each other. Since the data consist of only 24 points, to be sorted in 9 groups, this is done manually by checking closest distances and averaging between them. Note the galaxies were grouped together only if their distances were less than $0.1$. Once the groups were made, the maximum velocity of the corresponding group was considered as the Y-data point. \\
# This was done for sole purpose of getting as close the value Hubble obtained on his paper i.e. $H_0 \sim 500 km/s.Mpc $.

# %%
# distances in Mpc, velocities in km/s
tempr = np.array([0.033, 0.256 , 0.483, 0.63 , 0.88, 1.067 , 1.4 , 1.7, 2.0])
#tempv = np.array([230.0, -151.25, 253.33, 200.0,  314.0, 623.34, 500.0, 960.0, 810.0 ])
tempv = np.array([290.0, -220, 290, 200.0,  650, 920 , 500.0 , 960.0, 1090 ])
#tempv = np.array([170, -70 , 200, 200, -30, 450, 500, 960, 500 ])

# %%
ng = len(tempr)   # number of galaxy groups

if ng <= 2 :
    print ('Error! Need at least two data points!')
    exit()

# Use our home-grown version
[a0, a1, sigmag, sigma_a0, sigma_a1] = least_squares(tempr,tempv)

# Check against numpy's version:
#p,cov = np.polyfit( tempr, tempv, 1, cov=True)

# Print out results
print (' Least squares fit of', n, 'data points and', ng, 'groups.')
print (' -----------------------------------')
print (" Hubble's constant slope   b = {0:6.2f} +- {1:6.2f}  km/s/Mpc".format( b, sigma_b))
print (" Intercept with r axis     a = {0:6.2f} +- {1:6.2f}  km/s".format( a, sigma_a))
print (' Estimated v error bar sigma =', round(sigma, 1), 'km/s')
print (" Hubble's constant slope of groups   a1 = {0:6.2f} +- {1:6.2f}  km/s/Mpc".format( a1, sigma_a1))
print (" Intercept with r axis of groups     a0 = {0:6.2f} +- {1:6.2f}  km/s".format( a0, sigma_a0))
print (' Estimated v error bar sigma of groups =', round(sigmag, 1), 'km/s')


rvals = np.linspace(0., 2.0, 21)
f1 = a0 + a1 * rvals
fnp = p[1] + p[0] * rvals
plt.figure(1)
plt.scatter( r, v, label = "Full Data" )
plt.scatter( tempr, tempv, label = "Groups")
plt.plot( rvals, f , label="Our fit")
plt.plot( rvals, f1, label="Groups")
#plt.plot( rvals, fnp, label = "numpy fit")
plt.xlabel("Distance (Mpc)")
plt.ylabel("Velocity (km/s)")
plt.legend()

plt.show()
# Out:
#  Least squares fit of 24 data points and 9 groups.
#  -----------------------------------
#  Hubble's constant slope   b = 454.16 +-  75.24  km/s/Mpc
#  Intercept with r axis     a = -40.78 +-  83.44  km/s
#  Estimated v error bar sigma = 232.9 km/s
#  Hubble's constant slope of groups   a1 = 536.14 +- 133.10  km/s/Mpc
#  Intercept with r axis of groups     a0 =  16.69 +- 150.19  km/s
#  Estimated v error bar sigma of groups = 250.0 km/s

# %% [markdown]
# $\textbf{Solution :}$
# Note that new fitted graph consiting of the groups is not the same as presented in Hubble's 1929 paper but the value of the slope or the Hubble's constant obtained was quite close to that in his paper.
# Hubble's value : $H_0 = 513 \pm 60 km/s.Mpc$
# Our obtained value : $H_{0(fit)} = 536.14 \pm 133.10 km/s.Mpc$
# So the age of the universe is given as :
# $t = \frac{1}{H_0}$

# %%
t = (1/a1)*((3.086*10**19)/(365*24*3600))
sigma_t = (sigma_a1/a1**2)*((3.086*10**19)/(365*24*3600))
print( "Age of the universe is around ~", round(t/10**9,3) ,"+-", round(sigma_t/10**9,3), "billion years")
# Out:
# Age of the universe is around ~ 1.825 +- 0.453 billion years
